# %%
# %reload_ext autoreload
# %autoreload 2
from src.KMeans import find_best_k, create_labels, box_results, twoD_viz

# %%
recent = pd.read_csv('data/recency.csv')
frequency = pd.read_csv('data/frequency.csv')

# %% [markdown]
# # K-Means for Recency Scores

# %%
sse = find_best_k(recent, 'recency', "Recency")

# %%
viz, df = create_labels(recent, 'recency', 4)
viz
# Out:
#            count         mean         std     min      25%     50%      75%     max
# clusters
# 0         1883.0   210.378120  333.761521  -266.0   -40.00    37.0   421.00  1060.0
# 1         1125.0  1894.823111  506.091565  1064.0  1438.00  1864.0  2339.00  2838.0
# 2         1172.0  3786.998294  492.026130  2843.0  3386.25  3823.0  4209.25  4581.0
# 3         1574.0  5393.006989  494.514924  4586.0  5000.00  5315.5  5771.00  6422.0

# %%
viz_results(df, 'clusters', 'recency', "Comparison of Recency Groups")

# %% [markdown]
# # K-Means for Frequency Scores

# %%
sse_freq = find_best_k(frequency, 'vpy', "Visits per Year")

# %%
freq_viz, freq_df = create_labels(frequency, ['vpy'], 3)
freq_viz
# Out:
#              vpy
#            count        mean         std         min         25%         50%         75%      max
# clusters
# 0         5618.0    7.184082   12.226348    0.140872    1.766589    3.090129    5.793651    91.25
# 1          100.0  185.774471   97.275607   97.333333  109.500000  143.192308  243.333333   365.00
# 2           36.0  745.208333  118.474492  547.500000  730.000000  730.000000  730.000000  1095.00

# %%
viz_results(freq_df, 'clusters', 'vpy', "Comparison of Frequency Groups")

# %%
freq_df['log_vpy'] = np.log(freq_df['vpy'])

# %%
twoD_viz(freq_df, 'tenure', 'log_vpy')

# %%
loyalists = freq_df[freq_df.vpy.between(2,4)].sort_values('tenure', ascending=False)

# %%
twoD_viz(loyalists, 'tenure', 'vpy')
